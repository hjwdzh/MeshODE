# %%
import sys
import os
import torch
import pyDeform
import trimesh

# %%
V1, F1, E1, V2G1, GV1, GE1 = pyDeform.LoadCadMesh("../../data/source.obj")
V2, F2, E2, V2G2, GV2, GE2 = pyDeform.LoadCadMesh("../../data/reference.obj")

# %%
m1 = trimesh.Trimesh(V1.numpy(), F1.numpy())
m1.show()
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <title>trimesh: threejs viewer</title>
#     <meta charset=&quot;utf-8&quot;>
#     <meta name=&quot;viewport&quot; content=&quot;width=device-width,
# 		   user-scalable=no,
# 		   minimum-scale=1.0,
# 		   maximum-scale=1.0&quot;>
#     <style>
#       body {
#       margin: 0px;
#       overflow: hidden;
#       }
#     </style>
#   </head>
#   <body>
#     <div id=&quot;container&quot;></div>
#     <script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/three.js/109/three.min.js&quot;></script>
# ...

# %%
pc1 = trimesh.PointCloud(GV1.numpy())
pc1.show()

# %%
from open3d import JVisualizer
import open3d

# %%
pc1 = open3d.geometry.PointCloud(open3d.utility.Vector3dVector(GV1.numpy()))
visualizer = JVisualizer()
visualizer.add_geometry(pc1)
visualizer.show()
# Out:
# JVisualizer with 1 geometries

# %%
visualizer.show()
# Out:
# JVisualizer with 1 geometries
